# %%
import pandas as pd

# %%
df =pd.read_excel("C:/Users/Asus/dev/streamlit/esg insights/yfinance2.xlsx")
df
# Out:
#                              Name Symbols  Total ESG Score  Environment Score  \
# 0      Agilent Technologies, Inc.       A               15                0.3
# 1    American Airlines Group Inc.     AAL               29               11.5
# 2       Advance Auto Parts, Inc.      AAP               12                0.1
# 3                      Apple Inc.    AAPL               17                0.6
# 4                     AbbVie Inc.    ABBV               28                1.1
# ..                            ...     ...              ...                ...
# 432               Dentsply Sirona    XRAY               16                2.2
# 433                    Xylem Inc.     XYL               16                4.0
# 434                   Yum! Brands     YUM               21                4.0
# 435                 Zimmer Biomet     ZBH               27                4.0
# 436                        Zoetis     ZTS               18                1.0
#
# ...

# %%
option=['Healthcare']
df1=df.loc[df['Sector'].isin(option)]
df1.head(5)
# Out:
#                                    Name Symbols  Total ESG Score  \
# 0            Agilent Technologies, Inc.       A               15
# 4                           AbbVie Inc.    ABBV               28
# 5   AmerisourceBergen Corporation (ABC)     ABC               12
# 6                   Abbott Laboratories     ABT               25
# 27                           Amgen Inc.    AMGN               22
#
#     Environment Score  Social Score  Governance Score      Sector  \
# 0                 0.3           8.6               6.3  Healthcare
# 4                 1.1          16.8               9.9  Healthcare
# 5                 1.3           5.6               5.2  Healthcare
# 6                 3.0          13.6               8.4  Healthcare
# 27                0.7          13.5               7.9  Healthcare
#
#     Controversy Score       Controversy Assessment
# 0                   1           Little Controversy
# 4                   3  Relatively High Controversy
# ...

# %%
selected_company='Apple Inc.'
sector=df.loc[df['Name'] == selected_company]['Sector'].iloc[0]
# Out:
# Technology

# %%
peers=df.loc[df['Sector']==sector]
peers
# Out:
#                      Name Symbols  Total ESG Score  Environment Score  \
# 3              Apple Inc.    AAPL               17                0.6
# 8           Accenture plc     ACN               10                0.3
# 9              Adobe Inc.    ADBE               12                1.9
# 10   Analog Devices, Inc.     ADI               24               10.1
# 13          Autodesk Inc.    ADSK               16                3.4
# ..                    ...     ...              ...                ...
# 380              Teradyne     TER               16                6.0
# 388          Trimble Inc.    TRMB               13                3.0
# 395     Texas Instruments     TXN               20                9.0
# 411              Verisign    VRSN               21                5.0
# 418       Western Digital     WDC               11                1.0
#
#      Social Score  Governance Score      Sector  Controversy Score  \
# ...
